# %% [markdown]
# # Data types

# %%
name = 'shaikh ashfaque'  #string
age = 30 #numerical
city = 'delhi' # string
course = 'super30' #string
experience = 6.5 #float
graduation_year = 2026 #numerical
height = 5.7 #float
is_student = True #boolean
learning_goal = 'become an FDE' #string
professional = 'data scientist' #string

# %%
print(name)
print(age)
print(city)
print(course)
print(experience)
print(graduation_year)
print(height)
print(is_student)
print(learning_goal)
print(professional)
# Out:
# shaikh ashfaque
# 30
# delhi
# super30
# 6.5
# 2026
# 5.7
# True
# become an FDE
# data scientist

# %%
# string - sting is using to store text data and can be used single and double quotes
# int - int is using whole number 
# float - float is define with the help of decimal value
# boolean - bolean value is define by true or false / 1 & 0
 # True -- 1
 # false -- 0

# %%
name = "shaikh Ashfaque"
print(type(name))
# Out:
# <class 'str'>

# %%
# complex data type

num1 = 3 + 4j

# %%
# real 
# 4j imginary

num1.imag
# Out:
# 4.0

# %%
num1.real
# Out:
# 3.0
